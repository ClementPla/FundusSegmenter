# %%
from nntools.utils import Config
from multistyleseg.data.fundus.factory import ALL_DATASETS, get_datamodule_from_config, FundusDataset

# %%
config = Config("../../../../../configs/fundus.yaml")
datamodule = get_datamodule_from_config(
        config["datasets"], ALL_DATASETS, config["data"]
    )
# Out:
# WARNING:root:Mismatch between the size of the different input folders (longer 54, smaller 26)
# WARNING:root:Upsampling missing labels to fit the dataset's size (54)
# /home/clement/miniforge-pypy3/envs/dl/lib/python3.11/site-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# WARNING:root:Mismatch between the size of the different input folders (longer 54, smaller 26)
# WARNING:root:Upsampling missing labels to fit the dataset's size (54)
# WARNING:root:Mismatch between the size of the different input folders (longer 27, smaller 14)
# WARNING:root:Upsampling missing labels to fit the dataset's size (27)
# WARNING:root:Mismatch between the size of the different input folders (longer 1842, smaller 49)
# WARNING:root:Upsampling missing labels to fit the dataset's size (1842)
# ...

# %%
for train, val, test in zip(datamodule.train.datasets, datamodule.val.datasets, datamodule.test):
    print(f"Train: {train.id.split('_')[0]} N={len(train)}, Val: {val.id.split('_')[0]} N={len(val)}, Test: {test.id.split('_')[0]} N={len(test)}, total={len(train)+len(val)+len(test)}")
# Out:
# Train: IDRID N=46, Val: IDRID N=8, Test: IDRID N=27, total=81
# Train: FGADR N=1253, Val: FGADR N=220, Test: FGADR N=369, total=1842
# Train: MESSIDOR N=118, Val: MESSIDOR N=20, Test: MESSIDOR N=60, total=198
# Train: DDR N=383, Val: DDR N=149, Test: DDR N=225, total=757
# Train: RETLES N=1083, Val: RETLES N=191, Test: RETLES N=319, total=1593
